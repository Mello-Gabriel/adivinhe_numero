# %%
import random
a = random.randint(0,20)
while True:
  b= int(input('Valor de 0 a 20'))
  if b > a:
    print('Diminua o valor')
  elif b < a:
      print('Aumente o valor') 
  else:
    print('vc acertou')
    break
# Out:
# Valor de 0 a 207
# Diminua o valor
# Valor de 0 a 206
# vc acertou

# %%
import numpy as np
a = np.random.randint(0,999)
z= [1]
for x in z:
    np.random.seed(a)
    numero=np.random.randint(0,20)
    chute=int(input('Chute um número de 0 a 20 '))
    if chute > numero:
        print(str(chute) + ' é muito alto')
        z.append(1)
    if chute < numero:
        print(str(chute)+' é muito baixo')
        z.append(1)
    if chute == numero:
        print(str(chute) + ' está correto!')
        z = []
# Out:
# Chute um número de 0 a 20 1
# 1 é muito baixo
# Chute um número de 0 a 20 4
# 4 é muito baixo
# Chute um número de 0 a 20 15
# 15 é muito alto
# Chute um número de 0 a 20 10
# 10 é muito baixo
# Chute um número de 0 a 20 13
# 13 é muito alto
# Chute um número de 0 a 20 12
# 12 está correto!

# %%
import random 

if a = 'teesoura m

# %%
a = 
while True:
